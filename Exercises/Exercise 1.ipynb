# %% [markdown]
# 1. Loop ашиглан дараах хэлбэрээр `*` тэмдэгтийг хэвлэнэ үү!
#
# ```
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *
# ```
# 2. Хэрэглэгчээс орж ирсэн тэмдэгт мөрийг урвуугаар хөрвүүлэх код бичнэ үү!
# 3. Өгөгдсөн тоонуудад сондгой болон тэгш тоо хэд байгааг тоолох код бичнэ үү!
#     * Жишээ оролт: (1, 2, 3, 4, 5, 6, 7, 8, 9)
#     * Жишээ гаралт: Сондгой тоо 5, Тэгш тоо 4
# 4. 0-6 хүртэлх тоон цуваанаас 3 болон 6-аас бусад тоог хэвлэх код бичнэ үү!
# 5. 0-50 дунд орших Fibonacci тоон дарааллыг хэвлэх код бичнэ үү!. ( Жич: 1, 1, 2, 3, 5, 8, ... )
# 6. 1-50 хүртэлх тоон цувааг эхнээс нь хэвлэнэ. Ингэхдээ 5-д хуваагддаг тоонуудын оронд 'FIVE', 3-д хуваагддаг тоонуудын оронд 'THREE' гэж бичнэ.
# 7. Хэрэглэгчээс авсан текст дундаас тоон тэмдэгт хэдэн удаа орсон, үсэг хэдэн удаа орсонг олох код бичнэ үү!
#     * Жишээ оролт: Books 6.7
#     * Жишээ гаралт: Тоо 2, Үсэг 5
# 8. Loop ашиглан дараах хэлбэрээр тоонуудыг хэвлэнэ үү!
#
# ```
# 1
# 22
# 333
# 4444
# 55555
# 666666
# 7777777
# 88888888
# 999999999
# ```
